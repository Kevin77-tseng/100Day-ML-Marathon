# %%
#Day001-作業1

# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
#$ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#frac=fraction
def mean_squared_error(y, yp):
    mse = MSE = sum( (y - yp)**2) / len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 210.287
# The Mean absolute error is 11.395

# %%
#Day001-作業2

"""
請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：

1. 你選的這組資料為何重要
 "Air quality in northern Taiwan" in Datasets is air quality monitoring data from northern Taiwan in 2015. 
   這組2015年的空氣品質監控資料讓我們了解北台灣空氣中的有害物質濃度和危害程度. 尤其是國人熟知的PM2.5. 
   透過持續的監控, 擬定和執行空品改善計劃以維持國人健康.

     
2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
  This data is from Environmental Protection Administration, Executive Yuan, R.O.C. (Taiwan). Collected and summarized by Nelson Chu.

3. 蒐集而來的資料型態為何
   Excel CSV file format. 

4. 這組資料想解決的問題如何評估
   可看持續監控的PM2.5 濃度趨勢去評估空品改善計劃是否有效.

"""

# %%
#Day001-作業3

"""
想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
   車隊司機的平均薪資偏低, 如何有效提升. 是否提高乘客的見車率可增加載客率.

2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
   由車隊司機記錄每次載客的起點, 終點, 里程和時間. 由這些資料可知在那個時間的那個地點載客率較高. 

3. 蒐集而來的資料型態為何
   放進Excel file 可加總, 平均, 篩選等

4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
   由統計資料可得知在那個時間的那個地點載客率較高, 告知車隊司機往載客率較高的地點待車, 持續觀察是否載客率趨勢是往上增加.

"""
